# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Define column names
COLUMN_NAMES = [
    "Number of STAs", "Load", "Size(x)", "Size(y)", "Area", "Contention window",
    "Channel width", "Packet size", "Max RSSI", "Avg. RSSI", "Min. RSSI",
    "Avg. Probability of failure", "Throughput", "Average delay", "Total airtime", "Proportional airtime"
]

# Load dataset from txt file
def load_data(file_path):
    data = pd.read_csv(file_path, delim_whitespace=True, header=None, names=COLUMN_NAMES)
    return data

# Display statistics
def display_statistics(data):
    print("Statistics:\n", data.describe())

# Plot distribution of features
def plot_distributions(data):
    data.hist(figsize=(12, 10), bins=20)
    plt.show()

# Clean data (handle missing values, outliers, etc.)
def clean_data(data):
    data = data.dropna()  # Remove missing values
    return data

# Handle categorical data (if applicable)
def encode_categorical(data):
    label_encoders = {}
    for col in data.select_dtypes(include=['object']).columns:
        le = LabelEncoder()
        data[col] = le.fit_transform(data[col])
        label_encoders[col] = le
    return data, label_encoders

# Normalize data
def normalize_data(data):
    scaler = StandardScaler()
    normalized_data = scaler.fit_transform(data)
    return pd.DataFrame(normalized_data, columns=data.columns)

# Split data into train and test
def split_data(data, test_size=0.2):
    train, test = train_test_split(data, test_size=test_size, random_state=42)
    return train, test

# Train a linear regression model focusing on throughput
def train_linear_regression(train_data):
    X_train = train_data.drop(columns=["Throughput"])  # Features
    y_train = train_data["Throughput"]  # Target

    model = LinearRegression()
    model.fit(X_train, y_train)
    return model

# Evaluate model performance
def evaluate_model(model, test_data):
    X_test = test_data.drop(columns=["Throughput"])
    y_test = test_data["Throughput"]

    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    print(f"Mean Squared Error: {mse}")
    print(f"R^2 Score: {r2}")

    plt.scatter(y_test, y_pred)
    plt.xlabel("Actual Throughput")
    plt.ylabel("Predicted Throughput")
    plt.title("Actual vs Predicted Throughput")
    plt.show()

# Main processing function
def main():
    file_path = "/content/drive/MyDrive/AAX/Sem 1/dataset_Seminar1.txt"
    data = load_data(file_path)

    print("Dataset preview:\n", data.head())
    display_statistics(data)
    plot_distributions(data)

    data = clean_data(data)
    data, label_encoders = encode_categorical(data)
    normalized_data = normalize_data(data)

    train_data, test_data = split_data(normalized_data)

    model = train_linear_regression(train_data)
    evaluate_model(model, test_data)

    print("Train data shape:", train_data.shape)
    print("Test data shape:", test_data.shape)

if __name__ == "__main__":
    main()
# Out:
# <ipython-input-3-5887eed5e37e>:18: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_path, delim_whitespace=True, header=None, names=COLUMN_NAMES)
# Dataset preview:
#     Number of STAs        Load  Size(x)  Size(y)    Area  Contention window  \
# 0            40.0  60000000.0     22.0     39.0   858.0               63.0
# 1            35.0  52500000.0     20.0     33.0   660.0               31.0
# 2            16.0  12000000.0     34.0     14.0   476.0              255.0
# 3            37.0  18500000.0     35.0      7.0   245.0               31.0
# 4            18.0   4500000.0     36.0     35.0  1260.0              127.0
#
#    Channel width  Packet size   Max RSSI  Avg. RSSI  Min. RSSI  \
# 0           80.0       4000.0 -42.928330 -63.163012 -74.965338
# 1           40.0      10000.0 -47.815800 -63.298410 -72.847989
# 2           40.0       4000.0 -46.138494 -60.076333 -70.044800
# 3           80.0      10000.0 -42.708813 -60.141393 -72.029643
# 4          160.0       8000.0 -45.492991 -63.780783 -76.225550
#
#    Avg. Probability of failure    Throughput  Average delay  Total airtime  \
# 0                     0.415189  7.208644e+06   1.229466e+07       1.084041
# 1                     0.485311  1.545116e+07   1.275042e+07       1.111263
# 2                     0.099413  6.743660e+06   2.251690e+06       0.880036
# 3                     0.493704  1.675025e+07   1.211374e+07       1.126341
# 4                     0.011664  4.500000e+06   1.446000e-03       0.276770
#
#    Proportional airtime
# 0              0.875490
# 1              0.873785
# 2              0.849701
# 3              0.860103
# 4              0.275687
# Statistics:
#         Number of STAs          Load        Size(x)        Size(y)  \
# count   100000.000000  1.000000e+05  100000.000000  100000.000000
# mean        21.446170  2.140292e+07      20.562940      20.479640
# std         11.554365  1.852042e+07      11.545206      11.540626
# min          2.000000  5.000000e+05       1.000000       1.000000
# 25%         11.000000  7.250000e+06      11.000000      11.000000
# 50%         21.000000  1.600000e+07      21.000000      20.000000
# 75%         31.000000  3.000000e+07      31.000000      30.000000
# max         41.000000  8.200000e+07      40.000000      40.000000
#
#                 Area  Contention window  Channel width    Packet size  \
# count  100000.000000      100000.000000  100000.000000  100000.000000
# mean      421.270350         227.043920      75.106000    7997.580000
# std       360.344349         323.350855      53.704279    2825.532513
# min         1.000000           3.000000      20.000000    4000.000000
# 25%       120.000000          15.000000      20.000000    6000.000000
# 50%       320.000000          63.000000      80.000000    8000.000000
# 75%       640.000000         255.000000     160.000000   10000.000000
# max      1600.000000        1023.000000     160.000000   12000.000000
#
#             Max RSSI      Avg. RSSI      Min. RSSI  \
# count  100000.000000  100000.000000  100000.000000
# mean      -45.911165     -57.577426     -66.467827
# std         5.400265       6.108548       8.057528
# min       -81.405165     -81.405165     -84.333834
# 25%       -48.131476     -61.985000     -72.637078
# 50%       -44.111064     -58.163205     -67.997587
# 75%       -41.888821     -53.589525     -61.525848
# max       -40.863587     -40.865960     -40.865960
#
#        Avg. Probability of failure    Throughput  Average delay  \
# count                100000.000000  1.000000e+05   1.000000e+05
# mean                      0.226676  9.716009e+06   4.688176e+06
# std                       0.224848  4.958025e+06   7.875887e+06
# min                       0.000209  5.000000e+05   4.930000e-04
# 25%                       0.036429  6.187692e+06   2.145750e-03
# 50%                       0.126492  9.113764e+06   2.253349e+06
# 75%                       0.400686  1.343290e+07   8.224326e+06
# max                       0.765422  2.262273e+07   5.330772e+08
#
#        Total airtime  Proportional airtime
# count  100000.000000         100000.000000
# mean        0.780560              0.660724
# std         0.360426              0.256756
# min         0.019793              0.019792
# 25%         0.481082              0.473732
# 50%         0.857473              0.781014
# 75%         1.069432              0.866646
# max         1.449354              0.946776
# Mean Squared Error: 0.08013131848732774
# R^2 Score: 0.9201624748773765
# Train data shape: (80000, 16)
# Test data shape: (20000, 16)

# %% [markdown]
#  We are using linear regression to predict Throughput based on various network and spatial features from our dataset. We begin by loading it with specified column names and then providing basic statistics (with describe) and visualizations of the data(ploting). The data is cleaned (missing values removed), and any categorical columns are encoded using label encoding. It is then normalized using standard scaling to ensure all features are on the same scale. The dataset is split into training and testing sets (80/20 split), and a linear regression model is trained on the training data with Throughput as the target. Finally, the model is evaluated on the test data using Mean Squared Error (MSE) and R² Score. A scatter plot is shown comparing actual versus predicted throughput values to visualize model accuracy.
